# %%
# !pip3 install pandas
import pandas as pd
# Out:
# Collecting pandas
#   Downloading pandas-1.0.5-cp37-cp37m-manylinux1_x86_64.whl (10.1 MB)
#      |████████████████████████████████| 10.1 MB 8.2 MB/s eta 0:00:01    |███▍                            | 1.1 MB 924 kB/s eta 0:00:10     |████████▏                       | 2.6 MB 924 kB/s eta 0:00:09     |███████████▏                    | 3.5 MB 924 kB/s eta 0:00:08
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.1)
# Collecting pytz>=2017.2
#   Downloading pytz-2020.1-py2.py3-none-any.whl (510 kB)
#      |████████████████████████████████| 510 kB 6.5 MB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.18.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)
# Installing collected packages: pytz, pandas
# Successfully installed pandas-1.0.5 pytz-2020.1

# %%
df = pd.read_csv('ratings_train.txt', delimiter='\t')

# %%
# !pip3 install sklearn
from sklearn.model_selection import train_test_split
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-0.23.1-cp37-cp37m-manylinux1_x86_64.whl (6.8 MB)
#      |████████████████████████████████| 6.8 MB 788 kB/s eta 0:00:01     |███████████▎                    | 2.4 MB 788 kB/s eta 0:00:06     |████████████████████████████▊   | 6.1 MB 788 kB/s eta 0:00:01
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-2.1.0-py3-none-any.whl (12 kB)
# Requirement already satisfied: scipy>=0.19.1 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn) (1.18.4)
# Collecting joblib>=0.11
#   Downloading joblib-0.15.1-py3-none-any.whl (298 kB)
#      |████████████████████████████████| 298 kB 6.1 MB/s eta 0:00:01
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py) ... done
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=2397 sha256=6380d782c4fbf6d6673c4bf9cd74520d330979136926d2b09aac15b99fa031ed
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
# Successfully installed joblib-0.15.1 scikit-learn-0.23.1 sklearn-0.0 threadpoolctl-2.1.0

# %%
train_data, test_data = train_test_split(df, test_size=0.2)

# %%
train_data
# Out:
#              id                                           document  label
# 129285  8384935  Althought I hadn`t seen him in more than 10 ye...      1
# 144042  7436546                                   소재는 신선(?)한데 좀...      0
# 101154  5917046                               이런영화 만드는 이유는 무엇인가???      0
# 115421  6034079  태범&수영 이야기가 젤로 잼있어요 아기자기 넘 예뻐요^^ 분량이 더 많았으면 좋겠어요^^      1
# 79297   9488978                 서은채 최고입니다.이런 미인이 이제서야 나타다다니~넘 이뽀요~      1
# ...         ...                                                ...    ...
# 22605   8405241                     케이온을 논하는데 무슨말이필요하랴 그냥보면 답이나올것을      1
# 85840   6191951                           반전이 있고 잔잔함과 긴장감있는 수작이군요.      1
# 144161  6975192                                                 ㅡㅡ      0
# 94014   9809734                    보고 보고 또 봐도 채플린의 천재성을 인정하게 되는 명작      1
# 2594    7682256                  개인적으로 역대 가장 역겹고 재수없는 여주가 아닐까한다...      0
#
# [120000 rows x 3 columns]

# %%
test_data
# Out:
#               id                                           document  label
# 98388    7463202   자가머리에 뭐가들었는지.... 정말 이해가 안가네..... 이걸드라마라고 썼으니....      0
# 31045     332735                        악평하고 싶지는 않다. 다만 재미는 없다 확실히.      0
# 104734   2920724           별반개두 아깝다...보는동안 하품만나오게한영화;;그이상 그이하두아님...      0
# 68914    9365905  우리가 흔히 말하는 영화라고 하기엔 너무허접하고...그렇다고 에로비디오라고 하기엔 ...      0
# 65556    7924634                               귀순권고영화.. 뜻밖의 블록버스터..      0
# ...          ...                                                ...    ...
# 95025    6235334               이거 2008년에 개봉했던 지구가 멈추는 날보다 더 심하다 ㅡㅡ;      0
# 133488  10269758                                     전 별로 재미없어요....      0
# 118548   7916864  학교에서 선생님께서 보여주셨는데 아기자기하고 예쁜 케잌들 때문인지 자꾸 생각나네요 ...      1
# 58824    4989434                                   이걸로 무슨 여우주연상을???      0
# 77364    4444326                              기분 좋은 초콜릿의 유혹과 달콤한 치유      1
#
# [30000 rows x 3 columns]

# %%
# !pip3 install mxnet
# !pip3 install gluonnlp
# !pip3 install transformers
# !pip3 --no-cache-dir install torch
# !pip3 install git+https://git@github.com/SKTBrain/KoBERT.git@master

from kobert.pytorch_kobert import get_pytorch_kobert_model
# Out:
# Collecting mxnet
#   Downloading mxnet-1.6.0-py2.py3-none-any.whl (68.7 MB)
#      |████████████████████████████████| 68.7 MB 160 kB/s eta 0:00:011   |▌                               | 983 kB 766 kB/s eta 0:01:29     |▋                               | 1.4 MB 766 kB/s eta 0:01:28     |▉                               | 1.8 MB 766 kB/s eta 0:01:28     |█▏                              | 2.5 MB 3.4 MB/s eta 0:00:20     |███                             | 6.5 MB 3.6 MB/s eta 0:00:18     |███▌                            | 7.4 MB 3.6 MB/s eta 0:00:18     |████                            | 8.5 MB 3.6 MB/s eta 0:00:17     |██████▌                         | 14.0 MB 4.4 MB/s eta 0:00:13     |██████▉                         | 14.7 MB 4.4 MB/s eta 0:00:13     |████████▍                       | 17.9 MB 2.2 MB/s eta 0:00:23     |█████████▊                      | 20.8 MB 2.0 MB/s eta 0:00:24     |███████████                     | 23.7 MB 2.0 MB/s eta 0:00:23     |███████████▏                    | 24.0 MB 2.0 MB/s eta 0:00:23     |██████████████▏                 | 30.3 MB 3.5 MB/s eta 0:00:11     |███████████████▏                | 32.6 MB 6.5 MB/s eta 0:00:06     |███████████████████▊            | 42.3 MB 4.8 MB/s eta 0:00:06     |████████████████████████        | 51.6 MB 7.6 MB/s eta 0:00:03     |████████████████████████████▍   | 61.0 MB 6.1 MB/s eta 0:00:02     |█████████████████████████████▏  | 62.8 MB 6.1 MB/s eta 0:00:01
# Requirement already satisfied: requests<3,>=2.20.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (2.23.0)
# Collecting graphviz<0.9.0,>=0.8.1
#   Downloading graphviz-0.8.4-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: numpy<2.0.0,>1.16.0 in /usr/local/lib/python3.7/dist-packages (from mxnet) (1.18.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (1.25.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.20.0->mxnet) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests<3,>=2.20.0->mxnet) (2.6)
# Installing collected packages: graphviz, mxnet
# Successfully installed graphviz-0.8.4 mxnet-1.6.0
# Collecting gluonnlp
#   Downloading gluonnlp-0.9.1.tar.gz (252 kB)
#      |████████████████████████████████| 252 kB 851 kB/s eta 0:00:01    |███████████▋                    | 92 kB 794 kB/s eta 0:00:01
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from gluonnlp) (1.18.4)
# Collecting cython
#   Using cached Cython-0.29.20-cp37-cp37m-manylinux1_x86_64.whl (2.0 MB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from gluonnlp) (20.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->gluonnlp) (2.4.7)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from packaging->gluonnlp) (1.15.0)
# Building wheels for collected packages: gluonnlp
#   Building wheel for gluonnlp (setup.py) ... done
#   Created wheel for gluonnlp: filename=gluonnlp-0.9.1-cp37-cp37m-linux_x86_64.whl size=470183 sha256=c520d8153d908334dc7e411288e5c68d82ae8dd62cec8880c1aa4fe77bdc7425
#   Stored in directory: /root/.cache/pip/wheels/d7/dd/b2/c023f6c9c83fb46b10f62f77ea526c4dad6913b967941bbe99
# Successfully built gluonnlp
# Installing collected packages: cython, gluonnlp
# Successfully installed cython-0.29.20 gluonnlp-0.9.1
# Collecting transformers
#   Downloading transformers-3.0.0-py3-none-any.whl (754 kB)
#      |████████████████████████████████| 754 kB 813 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from transformers) (1.18.4)
# Collecting sacremoses
#   Downloading sacremoses-0.0.43.tar.gz (883 kB)
#      |████████████████████████████████| 883 kB 2.9 MB/s eta 0:00:01     |████████▌                       | 235 kB 2.9 MB/s eta 0:00:01     |██████████████▉                 | 409 kB 2.9 MB/s eta 0:00:01
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting regex!=2019.12.17
#   Downloading regex-2020.6.8-cp37-cp37m-manylinux2010_x86_64.whl (661 kB)
#      |████████████████████████████████| 661 kB 2.9 MB/s eta 0:00:01     |███████████                     | 225 kB 2.9 MB/s eta 0:00:01
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.91-cp37-cp37m-manylinux1_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 4.3 MB/s eta 0:00:01
# Collecting tokenizers==0.8.0-rc4
#   Downloading tokenizers-0.8.0rc4-cp37-cp37m-manylinux1_x86_64.whl (3.0 MB)
#      |████████████████████████████████| 3.0 MB 5.4 MB/s eta 0:00:01     |█████▊                          | 542 kB 5.4 MB/s eta 0:00:01     |█████████████▊                  | 1.3 MB 5.4 MB/s eta 0:00:01     |████████████████████████████    | 2.7 MB 5.4 MB/s eta 0:00:01
# Collecting tqdm>=4.27
#   Downloading tqdm-4.47.0-py2.py3-none-any.whl (66 kB)
#      |████████████████████████████████| 66 kB 2.7 MB/s eta 0:00:01
# Collecting filelock
#   Downloading filelock-3.0.12-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.4)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Collecting click
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 1.4 MB/s eta 0:00:01
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (0.15.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.25.9)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.4.5.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/lib/python3/dist-packages (from requests->transformers) (2.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-py3-none-any.whl size=894090 sha256=30a399a536ab7aeba371935ae4387ae40580f69d3a499904546721e5ddb7f618
#   Stored in directory: /root/.cache/pip/wheels/69/09/d1/bf058f7d6fa0ecba2ce7c66be3b8d012beb4bf61a6e0c101c0
# Successfully built sacremoses
# Installing collected packages: regex, click, tqdm, sacremoses, sentencepiece, tokenizers, filelock, transformers
# Successfully installed click-7.1.2 filelock-3.0.12 regex-2020.6.8 sacremoses-0.0.43 sentencepiece-0.1.91 tokenizers-0.8.0rc4 tqdm-4.47.0 transformers-3.0.0
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.5.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torch) (1.18.4)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from torch) (0.18.2)
# Collecting git+https://****@github.com/SKTBrain/KoBERT.git@master
#   Cloning https://****@github.com/SKTBrain/KoBERT.git (to revision master) to /tmp/pip-req-build-03bk5bhm
#   Running command git clone -q 'https://****@github.com/SKTBrain/KoBERT.git' /tmp/pip-req-build-03bk5bhm
# Building wheels for collected packages: kobert
#   Building wheel for kobert (setup.py) ... done
#   Created wheel for kobert: filename=kobert-0.1.1-py3-none-any.whl size=12720 sha256=aa56fffa54b304055cd74d18faccb5f17193e78a19c90c37fd0b793f79d117f5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ac28unad/wheels/d3/68/ca/334747dfb038313b49cf71f84832a33372f3470d9ddfd051c0
# Successfully built kobert
# Installing collected packages: kobert
# Successfully installed kobert-0.1.1

# %%
bertmodel, vocab = get_pytorch_kobert_model()
# Out:
# [█████████████████████████████████.................]
